# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft
import librosa
import librosa.display
import os

# %%
file_path = 'MyFriendSound.mp3'

# %%
data, sr = librosa.load(file_path, sr=None)

# %%
print(f"Durasi: {len(data)/sr:.2f} detik")
print(f"Sampel rate: {sr} Hz")
print(f"Banyak sampel: {len(data)}")
# Out:
# Durasi: 1.16 detik
# Sampel rate: 16000 Hz
# Banyak sampel: 18525

# %%
time = np.linspace(0, len(data)/sr, len(data))
plt.figure(figsize=(12, 4))
plt.plot(time, data)
plt.title('Sinyal dalam Domain Waktu')
plt.xlabel('Waktu (detik)')
plt.ylabel('Amplitudo')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
n = len(data)
data_fft = fft(data)
frequencies = np.fft.fftfreq(n, d=1/sr)

# %%
positive_freqs = frequencies[:n // 2]
magnitude = np.abs(data_fft)[:n // 2]

# %%
plt.figure(figsize=(12, 4))
plt.plot(positive_freqs, magnitude)
plt.title('Spektrum Frekuensi (FFT)')
plt.xlabel('Frekuensi (Hz)')
plt.ylabel('Magnitudo')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
dominant_freq = positive_freqs[np.argmax(magnitude)]
print(f"Frekuensi dominan: {dominant_freq:.2f} Hz")
# Out:
# Frekuensi dominan: 280.70 Hz

# %% [markdown]
# ## Penjelasan dan Refleksi
#
# Dalam tugas ini, saya menggunakan sinyal suara dari suara teman saya yang direkam secara langsung dalam format .mp3 dengan durasi 1.16 detik, memiliki sample rate 16.000 Hz, dan terdiri dari 18.525 sample.
#
# Proses pertama adalah menjabarkan sinyal dalam domain waktu dan ditampilkan dalam bentuk plot. Kemudian sinyal tersebut diubah ke domain frekuensi menggunakan algoritma FTF untuk mengevaluasi komponen komponen frekuensi nya.
#
# Dari hasil tersebut, terlihat bahwa banyak spektrum frekuensi memuncak signifikan di bawah 2000 Hz. Puncak tertinggi pada frekuensi 280.70 Hz yang merupakan frekuensi terbanyak dari sinyal suara tersebut.
